# %% [markdown]
# # Practice: [KP Title]
#
# **Concepts**: [List 2-3 key concepts]
# **Difficulty**: [Level 1/2/3]
# **Estimated**: [X minutes]
#
# ---
#
# ## Objective
#
# [What you'll learn by completing this exercise]
#
# **Instructions:**
# - Fill in the code where you see `### START CODE HERE ###` and `### END CODE HERE ###`
# - Do not modify the function signatures or test cases
# - Run all cells to verify your implementation

# %% [markdown]
# ## 1 - Import Required Libraries
#
# Run the cell below to import the necessary packages.

# %%
## Setup: Import required libraries
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ---
#
# ## 2 - TODO 1: [Clear instruction]
#
# **Exercise**: [Detailed description of what to implement]
#
# [Additional context or mathematical formulas if needed]
#
# **Hints**:
# - [Hint 1: High-level approach]
# - [Hint 2: Specific implementation detail]

# %%
# GRADED FUNCTION: function_name

def function_name(param1, param2):
    """
    [Function description]
    
    Arguments:
    param1 -- [description]
    param2 -- [description]
    
    Returns:
    result -- [description]
    """
    
    ### START CODE HERE ### ( X lines of code)
    result = None
    ### END CODE HERE ###
    
    return result

# %% [markdown]
# ###  Additional Hints
#
# <details>
# <summary>Click for Hint 1 (Conceptual)</summary>
#
# [High-level approach or strategy]
# </details>
#
# <details>
# <summary>Click for Hint 2 (Specific)</summary>
#
# [Point to relevant principle or formula]
# </details>
#
# <details>
# <summary>Click for Hint 3 (Partial Solution)</summary>
#
# ```python
# # Key pattern or structure
# [partial code showing the approach]
# ```
# </details>

# %% [markdown]
# ---
#
# ## 3 - Test Your Implementation
#
# Run the cell below to test your function.

# %%
# Test Case 1: [Description]
input1 = None  # [create_test_input]
expected1 = None  # [expected_output]
output1 = function_name(input1, None)
print("Test 1: " + str(output1))
assert output1 == expected1, "Test 1 failed"

# Test Case 2: [Description]
input2 = None  # [create_test_input]
expected2 = None  # [expected_output]
output2 = function_name(input2, None)
print("Test 2: " + str(output2))
assert output2 == expected2, "Test 2 failed"

# Test Case 3 (Edge case): [Description]
edge_input = None  # [create_edge_case]
edge_expected = None  # [expected_output]
output3 = function_name(edge_input, None)
print("Test 3 (Edge): " + str(output3))
assert output3 == edge_expected, "Edge case failed"

print('\n All tests passed!')

# %% [markdown]
# **Expected Output**:
#
# <table style="width:30%">
#   <tr>
#     <td>**Test 1**</td>
#     <td>[expected value]</td>
#   </tr>
#   <tr>
#     <td>**Test 2**</td>
#     <td>[expected value]</td>
#   </tr>
#   <tr>
#     <td>**Test 3**</td>
#     <td>[expected value]</td>
#   </tr>
# </table>

# %% [markdown]
# ---
#
# ## 4 - Reflection
#
# <font color='blue'>
# **What you should remember:**
#
# After completing this exercise, reflect on:
# 1. **Key Insight**: What was the main concept you learned?
# 2. **Real-world Application**: How would you apply this to solve a practical problem?
# 3. **Remaining Questions**: What aspects are still unclear or need further exploration?
# </font>
#
# ---
#
# **Optional Challenge**: [Suggest an extension or variation of the exercise]
